# %%
# %run train.py --log_file log_hest.txt --lr 1e-4 --batch_size 32 --epochs 100 --dataset adata --adata '/sibcb1/chenluonanlab8/zoujiawei/Final_version_with_foundation_model/data/ref_scGPT.h5ad' --exp_name './checkpoint/demo/'
# Out:
# 2025-12-23 08:20:39,118 - __main__ - INFO - Starting...
# 2025-12-23 08:20:39,149 - __main__ - INFO - Using device: cuda:0
# Take key teacher in provided checkpoint dict
# Pretrained weights found at /sibcb1/chenluonanlab8/zoujiawei/Final_version_with_foundation_model/img_encoder/HIPT_4K/Checkpoints/vit256_small_dino.pth and loaded with msg: _IncompatibleKeys(missing_keys=[], unexpected_keys=['head.mlp.0.weight', 'head.mlp.0.bias', 'head.mlp.2.weight', 'head.mlp.2.bias', 'head.mlp.4.weight', 'head.mlp.4.bias', 'head.last_layer.weight_g', 'head.last_layer.weight_v'])
# model_HPIT_load_success!
# 2025-12-23 08:20:42,659 - __main__ - INFO - Preparing data...
# /sibcb1/chenluonanlab8/zoujiawei/miniconda3/envs/CarfHe/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ...

# %%
import tifffile
image_path = '/sibcb1/chenluonanlab8/zoujiawei/HEST1k/hest_data/wsis/MISC70.tif'
with tifffile.TiffFile(image_path) as tif:
    # 只读取第一页（通常是最高分辨率层）
    whole_image = tif.pages[0].asarray()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# /var/tmp/ipykernel_1842371/3773434610.py in ?()
#       3 import tifffile
#       4 image_path = '/sibcb1/chenluonanlab8/zoujiawei/HEST1k/hest_data/wsis/MISC70.tif'
# ----> 5 with tifffile.TiffFile(image_path) as tif:
#       6     # 只读取第一页（通常是最高分辨率层）
#       7     whole_image = tif.pages[0].asarray()
#
# ~/miniconda3/envs/CarfHe/lib/python3.9/site-packages/tifffile/tifffile.py in ?(self, out, squeeze, lock, maxworkers, buffersize)
#    9428                     )
#    9429                     fh.open()
#    9430                 keyframe.decode  # init TiffPage.decode function under lock
#    9431
# -> 9432             result = create_output(out, keyframe.shaped, keyframe._dtype)
#    9433
#    9434             def func(
#    9435                 decoderesult: tuple[
#
# ...

# %%
# %run train_2.py --log_file log_BRCA_benchmark.txt --lr 1e-3 --batch_size 64 --epochs 200 --dataset adata --adata '/sibcb1/chenluonanlab8/zoujiawei/Final_version_with_foundation_model/data/BRCA_data_scGPT.h5ad' --exp_name './checkpoint/demo/'
# Out:
# 2025-09-30 11:12:46,017 - __main__ - INFO - Starting...
# 2025-09-30 11:12:46,017 - __main__ - INFO - Starting...
# 2025-09-30 11:12:46,017 - __main__ - INFO - Starting...
# 2025-09-30 11:12:46,017 - __main__ - INFO - Starting...
# 2025-09-30 11:12:46,017 - __main__ - INFO - Starting...
# 2025-09-30 11:12:46,017 - __main__ - INFO - Starting...
# 2025-09-30 11:12:46,017 - __main__ - INFO - Starting...
# 2025-09-30 11:12:46,017 - __main__ - INFO - Starting...
# 2025-09-30 11:12:46,017 - __main__ - INFO - Starting...
# 2025-09-30 11:12:46,022 - __main__ - INFO - Using device: cuda:0
# 2025-09-30 11:12:46,022 - __main__ - INFO - Using device: cuda:0
# 2025-09-30 11:12:46,022 - __main__ - INFO - Using device: cuda:0
# 2025-09-30 11:12:46,022 - __main__ - INFO - Using device: cuda:0
# 2025-09-30 11:12:46,022 - __main__ - INFO - Using device: cuda:0
# 2025-09-30 11:12:46,022 - __main__ - INFO - Using device: cuda:0
# 2025-09-30 11:12:46,022 - __main__ - INFO - Using device: cuda:0
# ...

# %%
1
# Out:
# 1

# %%
2
# Out:
# 2

# %%
3
# Out:
# 3

# %%
4
# Out:
# 4

# %%
5
# Out:
# 5

# %%
6
# Out:
# 6

# %%
7
# Out:
# 7

# %%
8
# Out:
# 8

# %%
9
# Out:
# 9
